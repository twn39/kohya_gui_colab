# %% [markdown]
# ## Kohya gui colab

# %%
# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb
# Out:
# /content
# env: TF_CPP_MIN_LOG_LEVEL=1
# 38 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2023-06-11 06:18:31--  http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# Resolving launchpadlibrarian.net (launchpadlibrarian.net)... 185.125.189.228, 185.125.189.229, 2620:2d:4000:1001::8007, ...
# Connecting to launchpadlibrarian.net (launchpadlibrarian.net)|185.125.189.228|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203696 (199K) [application/x-debian-package]
# Saving to: ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’
#
# libgoogle-perftools 100%[===================>] 198.92K  --.-KB/s    in 0.04s
#
# 2023-06-11 06:18:31 (5.10 MB/s) - ‘libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb’ saved [203696/203696]
#
# --2023-06-11 06:18:31--  https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# ...

# %%
from google.colab import drive
import os

if not os.path.exists("/content/drive"):
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/twn39/kohya_ss_colab.git
# Out:
# Cloning into 'kohya_ss_colab'...
# remote: Enumerating objects: 6129, done.
# remote: Counting objects: 100% (1507/1507), done.
# remote: Compressing objects: 100% (397/397), done.
# remote: Total 6129 (delta 1223), reused 1345 (delta 1108), pack-reused 4622
# Receiving objects: 100% (6129/6129), 5.27 MiB | 15.29 MiB/s, done.
# Resolving deltas: 100% (4232/4232), done.

# %%
# %cd /content/kohya_ss_colab/
# !bash ./setup.sh -n -v
# Out:
# /content/kohya_ss_colab
# Skipping git operations.
# Installing Python TK if not found on the system.
# Ubuntu detected.
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:9 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:10 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Reading package lists... Done
# Building dependency tree
# ...

# %%
# !accelerate config --config_file /content/kohya_ss_colab/config_files/accelerate/default_config.yaml default
# Out:
# 2023-06-11 06:55:38.533077: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
# !bash ./gui.sh --share --headless
# Out:
# ./gui.sh: line 17: /content/kohya_ss_colab/venv/bin/activate: No such file or directory
# 06:55:53-277876 INFO     nVidia toolkit detected
# 06:55:55-486154 INFO     Torch 2.0.1+cu118
# 06:55:55-521306 INFO     Torch backend: nVidia CUDA 11.8 cuDNN 8700
# 06:55:55-540621 INFO     Torch detected GPU: Tesla V100-SXM2-16GB VRAM 16151
#                          Arch (7, 0) Cores 80
# 06:55:55-544620 INFO     Verifying requirements
# 06:55:59-259968 INFO     headless: True
# 06:55:59-265983 INFO     Load CSS...
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://9f7f9df05494fb2e82.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# 06:57:27-798168 INFO     Copy /content/drive/MyDrive/datasets/pop_girl to
#                          /content/drive/MyDrive/lycoris/pop_girl/img/10_pop_girl
#                          girl...
# ...

# %%
root_dir = "/content"
deps_dir = os.path.join(root_dir, "deps")
repo_dir = os.path.join(root_dir, "kohya_ss_colab")

# @title ## Visualize loss graph (Optional)
training_logs_path = "/content/drive/MyDrive/lycoris/pop_girl/log"  # @param {type : "string"}

os.chdir(repo_dir)
# %load_ext tensorboard
# %tensorboard --logdir {training_logs_path}
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# 2023-06-11 07:37:59.092054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.33' not found (required by /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server)
# /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.34' not found (required by /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server)
# /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.32' not found (required by /usr/local/lib/python3.10/dist-packages/tensorboard_data_server/bin/server)
# ...

# %%
# %reload_ext tensorboard
